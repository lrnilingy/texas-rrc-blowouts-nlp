# %% [markdown]
# <a href="https://colab.research.google.com/github/lrnilingy/texas-rrc-blowouts-nlp/blob/master/scratch/rong/src/wordcloud_hamilton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import nltk
import matplotlib.pyplot as plt
% matplotlib inline

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/lrnilingy/texas-rrc-blowouts-nlp/master/scratch/rong/data/blowouts_new_cleaned.csv'
df = pd.read_csv(url, na_filter=False)
df.Remarks = df.Remarks.dropna()

# %%
df['Remarks'] = df['Remarks'].astype(str)
text = " ".join(Remarks for Remarks in df.Remarks)
print ("There are {} words in the combination of all remarks.".format(len(text)))
# Out:
# There are 47024 words in the combination of all remarks.

# %%
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 1:
            result.append(lemmatize_stemming(token))
    return result

# %%
# Create stopword list:
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
  
stopwords = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df.dtypes
# Out:
# District               object
# Date                   object
# Operator               object
# Lease/Facility Name    object
# Lease/ID               object
# API#                   object
# Drill Permit #         object
# Well #                 object
# Field Name             object
# County                 object
# Fire                   object
# H2S                    object
# Injuries               object
# Deaths                 object
# Remarks                object
# dtype: object

# %%
wordcloud = WordCloud(width=1000, height=800, max_words=50).generate(text)
plt.figure(figsize=(20, 10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
